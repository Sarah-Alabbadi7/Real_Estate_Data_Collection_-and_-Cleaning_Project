# %% [markdown]
# ## project

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %% [markdown]
# # hilal sale

# %%
# Headers to mimic browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# Base URL and template
BASE_URL = "https://hilalprp.com.om"
URL_TEMPLATE = BASE_URL + "/properties-search/page/{}/?status=for-sale"
MAX_PAGES = 100  # Safety limit

# Data storage
properties = {
    "Title": [],
    "Location": [],
    "Bedrooms": [],
    "Bathrooms": [],
    "Garage": [],
    "Price": [],
    "Size": [],
    "Listing_Type": []
}

# Loop through pages
for page in range(1, MAX_PAGES + 1):
    url = URL_TEMPLATE.format(page)
    print(f"\nScraping page {page}: {url}")
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except Exception as e:
        print(f"Failed to fetch page {page}: {e}")
        break

    soup = BeautifulSoup(response.text, "html.parser")
    listings = soup.find_all("article", class_="rh_list_card")
    
    if not listings:
        print("No listings found.")
        break

    for listing in listings:
        # Title
        title_tag = listing.find("h3")
        title = title_tag.get_text(strip=True) if title_tag else "N/A"

        # Price
        price_tag = listing.find("p", class_="price")
        price = price_tag.get_text(strip=True).replace("OMR", "").replace(",", "").strip() if price_tag else "N/A"

        # Listing Type (for-sale)
        status_tag = listing.find("span", class_="status")
        listing_type = status_tag.get_text(strip=True) if status_tag else "For Sale"

        # Meta Info
        meta_dict = {"Bedrooms": "N/A", "Bathrooms": "N/A", "Garage": "N/A", "Size": "N/A"}
        meta_wrap = listing.find_all("div", class_="rh_prop_card__meta")

        for block in meta_wrap:
            label = block.find("span", class_="rh_meta_titles")
            value = block.find("span", class_="figure")
            if label and value:
                label_text = label.get_text(strip=True).lower()
                val_text = value.get_text(strip=True)
                if "bedroom" in label_text or "room" in label_text:
                    meta_dict["Bedrooms"] = val_text
                elif "bathroom" in label_text:
                    meta_dict["Bathrooms"] = val_text
                elif "garage" in label_text:
                    meta_dict["Garage"] = val_text
                elif "area" in label_text or "size" in label_text or "sqmt" in label_text:
                    meta_dict["Size"] = val_text

        # Location (from detail page)
        location = "N/A"
        detail_link_tag = listing.find("a", href=True)
        if detail_link_tag:
            detail_url = detail_link_tag["href"]
            try:
                detail_resp = requests.get(detail_url, headers=headers)
                detail_resp.raise_for_status()
                detail_soup = BeautifulSoup(detail_resp.content, "html.parser")
                location_tag = detail_soup.find("a", href=lambda x: x and "/property-city/" in x)
                if location_tag:
                    location = location_tag.get_text(strip=True)
            except Exception as e:
                print(f"Error fetching detail page: {e}")

        # Append data
        properties["Title"].append(title)
        properties["Location"].append(location)
        properties["Bedrooms"].append(meta_dict["Bedrooms"])
        properties["Bathrooms"].append(meta_dict["Bathrooms"])
        properties["Garage"].append(meta_dict["Garage"])
        properties["Price"].append(price)
        properties["Size"].append(meta_dict["Size"])
        properties["Listing_Type"].append(listing_type)

    time.sleep(1)  # polite pause

# Convert to DataFrame
df = pd.DataFrame(properties)
print("\nSample data:")
print(df.head(10))

# Export to CSV
df.to_csv("hilal_sale_data.csv", index=False)
print("\nSaved to hilal_sale_data.csv")
# Out:
# Scraping page 1: https://hilalprp.com.om/properties-search/page/1/?status=for-sale
#
# Scraping page 2: https://hilalprp.com.om/properties-search/page/2/?status=for-sale
#
# Scraping page 3: https://hilalprp.com.om/properties-search/page/3/?status=for-sale
#
# Scraping page 4: https://hilalprp.com.om/properties-search/page/4/?status=for-sale
#
# Scraping page 5: https://hilalprp.com.om/properties-search/page/5/?status=for-sale
#
# Scraping page 6: https://hilalprp.com.om/properties-search/page/6/?status=for-sale
#
# Scraping page 7: https://hilalprp.com.om/properties-search/page/7/?status=for-sale
#
# Scraping page 8: https://hilalprp.com.om/properties-search/page/8/?status=for-sale
# No listings found.
#
# Sample data:
#                         Title    Location Bedrooms Bathrooms    Garage  \
# 0         3-BEDROOM APARTMENT     Bausher        3       N/A    SHADED
# 1             3-BEDROOM VILLA  Al Mawaleh        4       N/A    SHADED
# 2        6-BEDROOM TWIN VILLA     Bausher        7       N/A    SHADED
# 3    7-BEDROOM DETACHED VILLA    Al Ansab        9       N/A    SHADED
# 4    4-BEDROOM DETACHED VILLA     Al Hail        6       N/A    SHADED
# 5        5-BEDROOM TWIN VILLA    Al Ansab        7       N/A  UNSHADED
# 6        7-BEDROOM TWIN VILLA         N/A        8       N/A    SHADED
# 7  6+1 BEDROOM DETACHED VILLA     Bausher        7       N/A    SHADED
# 8  4+1 BEDROOM COMPOUND VILLA   Al Khoudh        5       N/A   OUTSIDE
# 9    7-BEDROOM DETACHED VILLA    Al Ansab        9       N/A    SHADED
#
#     Price Size        Listing_Type
# 0   45000  N/A            For Sale
# 1  290000  N/A            For Sale
# 2  180000  N/A            For Sale
# 3  300000  758            For Sale
# 4   80000  N/A            For Sale
# 5     700  N/A  For Rent, For Sale
# 6  105000  573            For Sale
# 7     180  N/A            For Sale
# 8   80000  260            For Sale
# 9     220  N/A            For Sale
#
# Saved to hilal_sale_data.csv

# %%
df = pd.DataFrame(properties)
df
# Out:
#                                        Title    Location Bedrooms Bathrooms  \
# 0                        3-BEDROOM APARTMENT     Bausher        3       N/A
# 1                            3-BEDROOM VILLA  Al Mawaleh        4       N/A
# 2                       6-BEDROOM TWIN VILLA     Bausher        7       N/A
# 3                   7-BEDROOM DETACHED VILLA    Al Ansab        9       N/A
# 4                   4-BEDROOM DETACHED VILLA     Al Hail        6       N/A
# ..                                       ...         ...      ...       ...
# 58                  6-BEDROOM DETACHED VILLA     Al Hail       +9       N/A
# 59                       3 BEDROOM TOWNHOUSE   Al Khoudh        3       N/A
# 60    8 BEDROOM DETACHED VILLA IN (MAWALLEH)  Al Mawaleh        8       N/A
# 61  7 BEDROOM DETACHED VILLA IN (AL KHUWAIR)  Al Khuwair        8       N/A
# 62       FULLY FURNISHED 2 BEDROOM APARTMENT     Salalah        2       N/A
#
#             Garage    Price    Size Listing_Type
# 0           SHADED    45000     N/A     For Sale
# 1           SHADED   290000     N/A     For Sale
# 2           SHADED   180000     N/A     For Sale
# 3           SHADED   300000     758     For Sale
# 4           SHADED    80000     N/A     For Sale
# ..             ...      ...     ...          ...
# 58  SHADED OUTSIDE   300000     N/A     For Sale
# 59        UNSHADED    80000     199     For Sale
# 60               4  -320000     670     For Sale
# 61               1    85000     N/A     For Sale
# 62               1    90000  129.35     For Sale
#
# [63 rows x 8 columns]

# %% [markdown]
# # Data Cleaning & Integration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         63 non-null     object
#  1   Location      63 non-null     object
#  2   Bedrooms      63 non-null     object
#  3   Bathrooms     63 non-null     object
#  4   Garage        63 non-null     object
#  5   Price         63 non-null     object
#  6   Size          63 non-null     object
#  7   Listing_Type  63 non-null     object
# dtypes: object(8)
# memory usage: 4.1+ KB

# %%
df.head(30)
# Out:
#                                                 Title             Location  \
# 0                                 3-BEDROOM APARTMENT              Bausher
# 1                                     3-BEDROOM VILLA           Al Mawaleh
# 2                                6-BEDROOM TWIN VILLA              Bausher
# 3                            7-BEDROOM DETACHED VILLA             Al Ansab
# 4                            4-BEDROOM DETACHED VILLA              Al Hail
# 5                                5-BEDROOM TWIN VILLA             Al Ansab
# 6                                7-BEDROOM TWIN VILLA                  N/A
# 7                          6+1 BEDROOM DETACHED VILLA              Bausher
# 8                          4+1 BEDROOM COMPOUND VILLA            Al Khoudh
# 9                            7-BEDROOM DETACHED VILLA             Al Ansab
# 10                                     4+1 TWIN VILLA      Shatti Al Qurum
# 11                           6 BEDROOM DETACHED VILLA             Maabelah
# 12        3BEDROOM FURNISHED TWIN VILLA IN (AL KHOUD)            Al Khoudh
# 13                      FARM LAND FOR SALE IN (BARKA)                Barka
# 14                      FARM LAND FOR SALE IN (BARKA)                Barka
# 15                           FARM FOR SALE IN (BARKA)                Barka
# 16                           9 BEDROOM DETACHED VILLA                Qurum
# 17          8 BEDROOM TWIN VILLA IN ( AL-HAIL NORTH )              Al Hail
# 18                         5 BEDROOM VILLA IN (QURUM)                Qurum
# 19                      6 BEDROOM VILLA IN (ALKHOUDH)            Al Khoudh
# 20                       5 BEDROOM VILLA IN (BAUSHER)              Bausher
# 21                       6 BEDROOM VILLA IN (BAUSHER)              Bausher
# 22                  5 BEDROOM TWINVILLA IN (AL ANSAB)             Al Ansab
# 23                5 BEDROOM TWINVILLA IN (AL MAWALEH)              Bausher
# 24            5 BEDROOM DETACHED VILLA IN ( AL ANSAB)             Al Ansab
# 25  FURNISHED 5 BEDROOM VILLA IN ( MADINAT SULTAN ...  Madinat Qaboos (MQ)
# 26               5 BEDROOM TWIN-VILLA IN ( MAABELLAH)             Maabelah
# 27  5 BEDROOM TWINVILLA IN ( MADINAT AL SULTAN QAB...  Madinat Qaboos (MQ)
# 28                    5 BEDROOM VILLA IN ( QURUM 20 )                Qurum
# 29                       9 BEDROOM VILLA IN (BAUSHER)              Bausher
#
#    Bedrooms Bathrooms    Garage   Price  Size        Listing_Type
# 0         3       N/A    SHADED   45000   N/A            For Sale
# 1         4       N/A    SHADED  290000   N/A            For Sale
# 2         7       N/A    SHADED  180000   N/A            For Sale
# 3         9       N/A    SHADED  300000   758            For Sale
# 4         6       N/A    SHADED   80000   N/A            For Sale
# 5         7       N/A  UNSHADED     700   N/A  For Rent, For Sale
# 6         8       N/A    SHADED  105000   573            For Sale
# 7         7       N/A    SHADED     180   N/A            For Sale
# 8         5       N/A   OUTSIDE   80000   260            For Sale
# 9         9       N/A    SHADED     220   N/A            For Sale
# 10        5       N/A    SHADED    1000   N/A  For Rent, For Sale
# 11        8       N/A       N/A  200000   N/A            For Sale
# 12        4       N/A       N/A  105000   300            For Sale
# 13      N/A       N/A       N/A  170000  7502            For Sale
# 14      N/A       N/A       N/A  140000  5544            For Sale
# 15        6       N/A       N/A  200000  6117            For Sale
# 16        9       N/A       N/A  166000   405            For Sale
# 17        9       N/A       yes  180000   520            For Sale
# 18        5       N/A         2  175000   180            For Sale
# 19        8       N/A         2  145000   280            For Sale
# 20        8       N/A         3  220000   350            For Sale
# 21        7       N/A       N/A  220000   285            For Sale
# 22        6       N/A         3  140000   500            For Sale
# 23        6       N/A         2   85000   N/A            For Sale
# 24        8       N/A         3  255000   660            For Sale
# 25        6       N/A         2  185000   370            For Sale
# 26        7       N/A         2   75000   300            For Sale
# 27        5       N/A         2  265000   284            For Sale
# 28        5       N/A         2  110000   209            For Sale
# 29        9       N/A         2  200000   334            For Sale

# %%
df.describe(include='all')
# Out:
#                            Title Location Bedrooms Bathrooms Garage  Price  \
# count                         63       63       63        63     63     63
# unique                        59       18       11         1     10     40
# top     7-BEDROOM DETACHED VILLA  Bausher        6       N/A      2  85000
# freq                           2       11       13        63     23      5
#
#        Size Listing_Type
# count    63           63
# unique   41            2
# top     N/A     For Sale
# freq     16           60

# %%
df.Location.unique()
# Out:
# array(['Bausher', 'Al Mawaleh', 'Al Ansab', 'Al Hail', 'N/A', 'Al Khoudh',
#        'Shatti Al Qurum', 'Maabelah', 'Barka', 'Qurum',
#        'Madinat Qaboos (MQ)', 'Mutrah', 'Muscat Hills', 'Rusayl',
#        'Al Ghoubrah', 'MUSCAT BAY', 'Al Khuwair', 'Salalah'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Title           0
# Location        0
# Bedrooms        0
# Bathrooms       0
# Garage          0
# Price           0
# Size            0
# Listing_Type    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking null values
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Title, Location, Bedrooms, Bathrooms, Garage, Price, Size, Listing_Type]
# Index: []

# %%
df.dtypes
# Out:
# Title           object
# Location        object
# Bedrooms        object
# Bathrooms       object
# Garage          object
# Price           object
# Size            object
# Listing_Type    object
# dtype: object

# %%
df
# Out:
#                                        Title    Location Bedrooms Bathrooms  \
# 0                        3-BEDROOM APARTMENT     Bausher        3       N/A
# 1                            3-BEDROOM VILLA  Al Mawaleh        4       N/A
# 2                       6-BEDROOM TWIN VILLA     Bausher        7       N/A
# 3                   7-BEDROOM DETACHED VILLA    Al Ansab        9       N/A
# 4                   4-BEDROOM DETACHED VILLA     Al Hail        6       N/A
# ..                                       ...         ...      ...       ...
# 58                  6-BEDROOM DETACHED VILLA     Al Hail       +9       N/A
# 59                       3 BEDROOM TOWNHOUSE   Al Khoudh        3       N/A
# 60    8 BEDROOM DETACHED VILLA IN (MAWALLEH)  Al Mawaleh        8       N/A
# 61  7 BEDROOM DETACHED VILLA IN (AL KHUWAIR)  Al Khuwair        8       N/A
# 62       FULLY FURNISHED 2 BEDROOM APARTMENT     Salalah        2       N/A
#
#             Garage    Price    Size Listing_Type
# 0           SHADED    45000     N/A     For Sale
# 1           SHADED   290000     N/A     For Sale
# 2           SHADED   180000     N/A     For Sale
# 3           SHADED   300000     758     For Sale
# 4           SHADED    80000     N/A     For Sale
# ..             ...      ...     ...          ...
# 58  SHADED OUTSIDE   300000     N/A     For Sale
# 59        UNSHADED    80000     199     For Sale
# 60               4  -320000     670     For Sale
# 61               1    85000     N/A     For Sale
# 62               1    90000  129.35     For Sale
#
# [63 rows x 8 columns]
